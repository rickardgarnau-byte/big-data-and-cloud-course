# %% [markdown]
# # PySpark introduction

# %% [markdown]
# ## Row object in PySpark

# %%
from pyspark.sql import Row

row1 = Row(name = "Bella", animal_type = "rabbit", age = 4)
row1

# %%
row2 = Row(name = "Grogu", animal_type = "yoddle", age = 50)
row2

# %% [markdown]
# ## Create spark dataframe
#
# can be created from
# - Row
# - list of dicts
# - table
# - csv
# - parquet
# - database
# - existing dataframes
# ...

# %%
df = spark.createDataFrame([row1, row2])
df

# %%
df.show()

# %%
df.take(2)

# %%
display(df.take(2))

# %%
display(df)

# %%
employees = [
    {"name": "John D.", "age": 30, "department": "HR"},
    {"name": "Alice D.", "age": 32, "department": "Finance"},
    {"name": "Bob D.", "age": 20, "department": "IT"},
    {"name": "Henrik D.", "age": 40, "department": "Marketing"}
]

df_employees = spark.createDataFrame(employees)
df_employees

# %%
display(df_employees)

# %%
df_employees.take(3)

# %% [markdown]
# ## Read from csv file

# %%
from pathlib import Path
import pandas as pd

# Use absolute path to the data directory
DATA_PATH = Path("/Workspace/Users/rickard.garnau@stud.sti.se/big-data-and-cloud-course/data")

print(DATA_PATH)

# Workaround for serverless: read with pandas first, then convert to Spark
pd_athletes = pd.read_csv(DATA_PATH / "athlete_events.csv")
df_athletes = spark.createDataFrame(pd_athletes)

display(df_athletes.take(5))

# %%
df_athletes.printSchema()

# %%
print(df_athletes.columns)

# %%
from pyspark.sql.types import StructField, StringType, IntegerType, StructType, ByteType, ShortType
import pandas as pd

schema = StructType([
    StructField("ID", IntegerType(), True),
    StructField("Name", StringType(), True),
    StructField("Sex", StringType(), True),
    StructField("Age", ByteType(), True),
    StructField("Height", ShortType(), True),
    StructField("Weight", ShortType(), True),
    StructField("Team", StringType(), True),
    StructField("NOC", StringType(), True),
    StructField("Games", StringType(), True),
    StructField("Year", ShortType(), True),
    StructField("Season", StringType(), True),
    StructField("City", StringType(), True),
    StructField("Sport", StringType(), True),
    StructField("Event", StringType(), True),
    StructField("Medal", StringType(), True)
])

# Workaround for serverless: read with pandas first, then convert to Spark with schema
pd_athletes_schema = pd.read_csv(DATA_PATH / "athlete_events.csv")
df_athletes_schema = spark.createDataFrame(pd_athletes_schema, schema=schema)

display(df_athletes_schema.take(5))

# %% [markdown]
# ## EDA
#
# - calculate nulls

# %%
from pyspark.sql.functions import col, sum
nulls = df_athletes_schema.select([sum(col(c).isNull().cast("int")).alias(c) for c in df_athletes_schema.columns])

display(nulls)

# %%
df_athletes_schema.groupBy("NOC").count().filter("NOC IN ('SWE','NOR','FIN','DEN','ICE')"
).show()

# %% [markdown]
# ### combining SQL and dataframes

# %%
df_athletes_schema.createOrReplaceTempView("df_athletes_schema")

df_swe_medals = spark.sql("""
                          SELECT
                          sport, count(medal) as medals
                          FROM df_athletes_schema
                          WHERE noc = 'SWE' AND medal IN ('Gold', 'Silver', 'Bronze')
                          GROUP BY sport
                          ORDER BY medals DESC
                          """)
display(df_swe_medals)

# %%
fig = df_swe_medals.plot(kind="bar", x = "medals", y = "sport", title = "Swedish medals by sport")

fig.update_layout(yaxis = {"autorange": "reversed"})

# %% [markdown]
# ### SQL cells

# %%
df

# %%
# %sql
FROM df_athletes_schema Limit 1

# %%
# %sql

SHOW CATALOGS;

DROP CATALOG IF EXISTS data CASCADE;
