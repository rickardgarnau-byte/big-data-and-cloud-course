-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS IN data;

-- %%
SHOW VOLUMES IN data.olympic_games;

LIST '/Volumes/data/olympic_games/rawr_data';

-- %%
%python
_sqldf.display()

-- %%
%python

volume_path = '/Volumes/data/olympic_games/rawr_data'

files_in_volume = spark.sql(f"LIST '{volume_path}';")
files_in_volume # lazy evaluation, we see the schema, not the actual data

-- %%
%python
display(files_in_volume)
